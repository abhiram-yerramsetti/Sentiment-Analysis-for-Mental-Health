# %%
import pandas as pd

from nltk.tokenize import word_tokenize

# %%
# import autocorrect
# #

# %%
# df = pd.read_csv("E:\innomatics\ml\Sentiment Analysis for Mental Health\Combined Data.csv")

# %%
df
# Out:
#        Unnamed: 0                                          statement   status
# 0               0                                         oh my gosh  Anxiety
# 1               1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2               2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3               3  I've shifted my focus to something else but I'...  Anxiety
# 4               4  I'm restless and restless, it's been a month n...  Anxiety
# ...           ...                                                ...      ...
# 53038       53038  Nobody takes me seriously I’ve (24M) dealt wit...  Anxiety
# 53039       53039  selfishness  "I don't feel very good, it's lik...  Anxiety
# 53040       53040  Is there any way to sleep better? I can't slee...  Anxiety
# 53041       53041  Public speaking tips? Hi, all. I have to give ...  Anxiety
# 53042       53042  I have really bad door anxiety! It's not about...  Anxiety
#
# [53043 rows x 3 columns]

# %%
df['statement'].str.lower()
# Out:
# 0                                               oh my gosh
# 1        trouble sleeping, confused mind, restless hear...
# 2        all wrong, back off dear, forward doubt. stay ...
# 3        i've shifted my focus to something else but i'...
# 4        i'm restless and restless, it's been a month n...
#                                ...
# 53038    nobody takes me seriously i’ve (24m) dealt wit...
# 53039    selfishness  "i don't feel very good, it's lik...
# 53040    is there any way to sleep better? i can't slee...
# 53041    public speaking tips? hi, all. i have to give ...
# 53042    i have really bad door anxiety! it's not about...
# Name: statement, Length: 53043, dtype: object

# %%
# speller = autocorrect.Speller()

# %%
# df.drop_duplicates()

# %%
# def text_preprocess(text):
#     speller = autocorrect.Speller()
#     text = speller.autocorrect_sentence(text)
#     return text

# %%
# pip install emoji
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### eda

# %%
def eda(text):
    count = 0
    count = df[column].apply(lambda x: count + emoji.emoji_count(x)).sum()  #emoji count in the df
    upper =df[column].str.isupper().sum()
    url = df[column].apply(lambda x:   True  if re.search(r'www.\S+ | https?://\S+',x)  else False).sum()
    tags = df[column].apply(lambda x:   True  if re.search(r'<[^>]>+',x)  else False).sum()
    marks = df[column].apply(lambda x:   True  if re.search(r'[^a-zA-Z0-9 ]',x)  else False).sum()
    digits = df[column].apply(lambda x:   True  if re.search(r'[0-9]',x)  else False).sum()
    return  pd.Series({'Emoji':count,"upper case":upper,"urls" : url,"HTML tags":tags,'Punctuaton':marks,'Digits':digits})

# %%
eda(df,'statement')
# Out:
# Emoji           887
# upper case      297
# urls            463
# HTML tags         0
# Punctuaton    42412
# Digits        16897
# dtype: int64

# %%
import emoji

import re

import nltk
from nltk.stem import PorterStemmer

from nltk.corpus import stopwords

# %%
chat = {
    'BRB': 'Be Right Back',
    'LOL': 'Laugh Out Loud',
    'OMG': 'Oh My God',
    'IDK': 'I Don\'t Know',
    'TTYL': 'Talk To You Later',
    'BTW': 'By The Way',
    'IMO': 'In My Opinion',
    'IRL': 'In Real Life',
    'FYI': 'For Your Information',
    'SMH': 'Shaking My Head',
    'TBH': 'To Be Honest',
    'NP': 'No Problem',
    'TY': 'Thank You',
    'BFF': 'Best Friends Forever',
    'G2G': 'Got To Go',
    'ROFL': 'Rolling On the Floor Laughing',
    'DM': 'Direct Message',
    'JK': 'Just Kidding',
    'TMI': 'Too Much Information',
    'ICYMI': 'In Case You Missed It',
    'NVM': 'Never Mind',
    'FOMO': 'Fear Of Missing Out',
    'YOLO': 'You Only Live Once',
    'BAE': 'Before Anyone Else',
    'HMU': 'Hit Me Up'
}

# %%
df = df.dropna()

# %%
def text_preprocess(text):

    # text = text.lower()
    
    # text = emoji.demojize(text).replace(':',' ')
    # text = re.sub(r'[^a-zA-Z0-9]',' ',text)
    # text = re.sub(r'<[^>]+>',' ',text)
    # text = ' '.join(map(lambda i: chat[i] if i in chat.keys() else i ,text.split())) 

    # text = [i for i in text if i not in stopwords.words('english')]
    
    return text

# %%
df['statement'] = df['statement'].apply(text_preprocess)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df['statement'] = df['statement'].apply(text_preprocess)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# ...

# %%
import os
os.getcwd()
# Out:
# 'e:\\innomatics\\ml\\Sentiment Analysis for Mental Health'

# %%
df.to_csv("cleaned.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.to_csv("cleaned.csv")
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv("cleaned.csv")

# %%
df.drop("Unnamed: 0",axis = 1 , inplace=True)

# %%
df
# Out:
#                                                statement   status
# 0                                             oh my gosh  Anxiety
# 1      trouble sleeping  confused mind  restless hear...  Anxiety
# 2      all wrong  back off dear  forward doubt  stay ...  Anxiety
# 3      i ve shifted my focus to something else but i ...  Anxiety
# 4      i m restless and restless  it s been a month n...  Anxiety
# ...                                                  ...      ...
# 52676  nobody takes me seriously i ve  24m  dealt wit...  Anxiety
# 52677  selfishness   i don t feel very good  it s lik...  Anxiety
# 52678  is there any way to sleep better  i can t slee...  Anxiety
# 52679  public speaking tips  hi  all  i have to give ...  Anxiety
# 52680  i have really bad door anxiety  it s not about...  Anxiety
#
# [52681 rows x 2 columns]

# %%
df.drop_duplicates()
# Out:
#                                                statement   status
# 0                                             oh my gosh  Anxiety
# 1      trouble sleeping  confused mind  restless hear...  Anxiety
# 2      all wrong  back off dear  forward doubt  stay ...  Anxiety
# 3      i ve shifted my focus to something else but i ...  Anxiety
# 4      i m restless and restless  it s been a month n...  Anxiety
# ...                                                  ...      ...
# 52478  anxiety cause faintness when standing up   as ...  Anxiety
# 52479  anxiety heart symptom does anyone else have th...  Anxiety
# 52480  travel anxiety hi all  long time anxiety suffe...  Anxiety
# 52481  fomo from things i m not involved in does anyo...  Anxiety
# 52482  getting through the day how do you get  anythi...  Anxiety
#
# [51064 rows x 2 columns]

# %%
df["status"].value_counts()
# Out:
# status
# Normal                  16343
# Depression              15404
# Suicidal                10652
# Anxiety                  3841
# Bipolar                  2777
# Stress                   2587
# Personality disorder     1077
# Name: count, dtype: int64

# %%
df1 = df.sample(20000)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.feature_extraction.text import CountVectorizer

bow = CountVectorizer(stop_words='english')

bow.fit(df1['statement'])
X = bow.transform(df1['statement']).toarray()
y = df1['status']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=23)

# %%
# D-Tree

from sklearn.tree import DecisionTreeClassifier

bt = DecisionTreeClassifier()
bt.fit(X_train,y_train)
y_pred = bt.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.63

# %%
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB()
nb.fit(X_train,y_train)
y_pred = nb.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.610909090909091

# %% [markdown]
# ### creating pipeline

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline

# %%
model = Pipeline([
    ('vectorizer', CountVectorizer(stop_words='english')),
    ('classifier', DecisionTreeClassifier())
])

# %%
model
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer(stop_words='english')),
#                 ('classifier', DecisionTreeClassifier())])

# %%
df2 = df.sample(20000)

# %%
A = df2["statement"]
B = df2["status"]

# %%
X_train, X_test, y_train, y_test = train_test_split(A, B, test_size=0.33, random_state=42)

# %%
y.value_counts()
# Out:
# status
# Normal                  6202
# Depression              5959
# Suicidal                3976
# Anxiety                 1458
# Bipolar                 1066
# Stress                   966
# Personality disorder     373
# Name: count, dtype: int64

# %%
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('vectorizer', CountVectorizer(stop_words='english')),
#                 ('classifier', DecisionTreeClassifier())])

# %%
new_statements = ['i m really worried  i want to cry ']
model.predict(new_statements)[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 2
#       1 new_statements = ['i m really worried  i want to cry ']
# ----> 2 model.predict(new_statements)[0]
#
# AttributeError: 'NoneType' object has no attribute 'predict'

# %%
import pickle

# %%
pickle.dump(model,open(r"E:\innomatics\ml\Sentiment Analysis for Mental Health\model.pkl",'wb'))

# %%
x = pickle.load(open(r"E:\innomatics\ml\Sentiment Analysis for Mental Health\model.pkl", 'rb'))

# %%
x.predict(new_statements)[0]
# Out:
# 'Anxiety'
